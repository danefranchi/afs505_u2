# %% [markdown]
# # Lesson 8 Practice: Seaborn
#
# Use this notebook to follow along with the lesson in the corresponding lesson notebook: [L08-Seaborn-Lesson.ipynb](./L08-Seaborn-Lesson.ipynb).

# %% [markdown]
# ## Instructions
# Follow along with the teaching material in the lesson. Throughout the tutorial sections labeled as "Tasks" are interspersed and indicated with the icon: ![Task](http://icons.iconarchive.com/icons/sbstnblnd/plateau/16/Apps-gnome-info-icon.png). You should follow the instructions provided in these sections by performing them in the practice notebook.  When the tutorial is completed you can turn in the final practice notebook. For each task, use the cell below it to write and test your code.  You may add additional cells for any task as needed or desired.

# %% [markdown]
# ## Task 1a Setup
#
# Import the following packages:
# + seaborn as sns
# + pandas as pd
# + numpy as np
# + matplotlib.pyplot as plt
#
# Activate the `%matplotlib inline` magic.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 2a Load Data
#
# + View available datasets by calling `sns.get_dataset_names`.
# + Choose one of those datasets and explore it.

# %% [markdown]
# What is the shape?

# %%
sns.get_dataset_names()
# Out:
# C:\Users\dfran\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file C:\Users\dfran\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
planets_df = sns.load_dataset('planets')
planets_df.shape
# Out:
# (1035, 6)

# %% [markdown]
# What are the columns?

# %%
planets_df.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %% [markdown]
#  What are the data types?

# %%
planets_df.dtypes
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %% [markdown]
# Are there missing values?

# %%
planets_df.isna().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %% [markdown]
# Are there duplicated rows?

# %%
planets_df.duplicated().sum()
planets_df[planets_df.duplicated()]
# Out:
#            method  number  orbital_period  mass  distance  year
# 903  Microlensing       1             NaN   NaN       NaN  2008
# 923  Microlensing       1             NaN   NaN       NaN  2009
# 926  Microlensing       2             NaN   NaN    4080.0  2012
# 957       Imaging       1             NaN   NaN       NaN  2008

# %% [markdown]
# For categorical columns find the unique set of categories.

# %%
planets_df['method'].nunique()
# Out:
# 10

# %% [markdown]
# Is the data tidy?

# %%
# it appears tidy

# %% [markdown]
# ## Task 2b Preview Seaborn
#
# Take some time to peruse the Seaborn [example gallery](https://seaborn.pydata.org/examples/index.html).  Indicate which plot types are most interesting to you. Which do you expect will be most useful with current research projects you may be working on?

# %% [raw]
# # lmplot, barplot, scatterplot, distplot, lineplot, facetgrid, pairgrid,
# # swarmplot

# %% [markdown]
# ## Task 3a Using `relplot`
#
# Experiment with the `size`, `hue` and `style` semantics by applying them to another example dataset of your choice.
#
# *You should produce three or more plots for this task.*

# %%
mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x="horsepower", y="mpg", data=mpg)

# %%
sns.relplot(x="horsepower", y="mpg", hue= "weight",data=mpg)

# %%
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %%
sns.relplot(x="horsepower", y="mpg",  hue= "weight",size="displacement",style="cylinders", data=mpg)

# %% [markdown]
# ## Task 4a: Explore built-in styles
#
# Using a dataset of your choice, practice creating a plot for each of these different styles:
#
# + darkgrid
# + whitegrid
# + dark
# + white
# + ticks

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': (1, 1, 1, 0),
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'patch.force_edgecolor': False,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid') 
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %%
sns.set_style('whitegrid') 
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %%
sns.set_style('dark') 
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %%
sns.set_style('white') 
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %%
sns.set_style('ticks') 
sns.relplot(x="horsepower", y="mpg", style="cylinders", data=mpg)

# %% [markdown]
# ## Task 4b
#
# Experiment with the style options and palettes introduced above. Create and demonstrate a style of your own using a dataset of your choice.

# %%
custom_style = {'font.family': ['sans-serif'],'figure.facecolor': 'white', 'xtick.color': '.15',
                'axes.edgecolor': '.16','patch.edgecolor': 'r'}
sns.set_style("dark", custom_style)
sns.relplot(x="horsepower", y="mpg", hue= "weight",data=mpg)

# %% [markdown]
# ## Task 5a
#
# Examine the [Seaborn gallery](https://seaborn.pydata.org/examples/index.html) and find **two to four plots** types that interest you. Re-create a version of those plots using a different data set (make any other style changes you wish).

# %%
tips = sns.load_dataset('tips')
custom_style = {'font.family': ['sans-serif'],'figure.facecolor': 'white', 'xtick.color': '.15',
                'axes.edgecolor': '.16','patch.edgecolor': 'r'}
sns.set_style("dark", custom_style)
sns.catplot(x="total_bill", y="tip", hue= "sex",data=tips)

# %%
sns.lmplot(x="total_bill", y="tip", hue= "sex",data=tips)

# %%
sns.barplot(x="total_bill", y="tip", hue= "sex",data=tips)

# %%
sns.kdeplot(x="total_bill", y="tip", hue= "sex",data=tips)

# %%
# notebook stopped posting output window
