# %%
import numpy as np

# %%
file = np.genfromtxt("iris.csv", dtype = 'float', delimiter = ',', skip_header = 1, usecols =(0,1,2,3))
print(file.shape)
#print(file)
# Out:
# (150, 4)

# %%
print(file[0:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
print(file[0,0])
print(file[0][0])
# Out:
# 5.1
# 5.1

# %%
#retrive first column
print(file[:,0])
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#  6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#  5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#  6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#  6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#  6.7 6.7 6.3 6.5 6.2 5.9]

# %%
#retrieve last 2 cells of last row and last 2 cells of second to last row
print(file[148:,2:])
print(file[-2:,-2:])
# Out:
# [[5.4 2.3]
#  [5.1 1.8]]
# [[5.4 2.3]
#  [5.1 1.8]]

# %%
#retrieve all values greater than 4
print(file[file>4])
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 4.4 5.4
#  5.1 5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 4.1 5.5
#  4.2 4.9 5.  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.
#  4.7 6.4 4.5 6.9 4.9 5.5 6.5 4.6 5.7 4.5 6.3 4.7 4.9 6.6 4.6 5.2 5.  5.9
#  4.2 6.  6.1 4.7 5.6 6.7 4.4 5.6 4.5 5.8 4.1 6.2 4.5 5.6 5.9 4.8 6.1 6.3
#  4.9 6.1 4.7 6.4 4.3 6.6 4.4 6.8 4.8 6.7 5.  6.  4.5 5.7 5.5 5.5 5.8 6.
#  5.1 5.4 4.5 6.  4.5 6.7 4.7 6.3 4.4 5.6 4.1 5.5 5.5 4.4 6.1 4.6 5.8 5.
#  5.6 4.2 5.7 4.2 5.7 4.2 6.2 4.3 5.1 5.7 4.1 6.3 6.  5.8 5.1 7.1 5.9 6.3
#  5.6 6.5 5.8 7.6 6.6 4.9 4.5 7.3 6.3 6.7 5.8 7.2 6.1 6.5 5.1 6.4 5.3 6.8
#  5.5 5.7 5.  5.8 5.1 6.4 5.3 6.5 5.5 7.7 6.7 7.7 6.9 6.  5.  6.9 5.7 5.6
#  4.9 7.7 6.7 6.3 4.9 6.7 5.7 7.2 6.  6.2 4.8 6.1 4.9 6.4 5.6 7.2 5.8 7.4
#  6.1 7.9 6.4 6.4 5.6 6.3 5.1 6.1 5.6 7.7 6.1 6.3 5.6 6.4 5.5 6.  4.8 6.9
#  5.4 6.7 5.6 6.9 5.1 5.8 5.1 6.8 5.9 6.7 5.7 6.7 5.2 6.3 5.  6.5 5.2 6.2
#  5.4 5.9 5.1]

# %%
#retrieve all rows that have at least one value of five
five = file > 5
rowsum = np.sum(five, axis = 1)

print(file[rowsum > 0,:].shape)
print(file[rowsum > 0,:])
# Out:
# (118, 4)
# [[5.1 3.5 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [5.4 3.7 1.5 0.2]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [5.1 3.3 1.7 0.5]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [5.5 3.5 1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.1 3.8 1.9 0.4]
#  [5.1 3.8 1.6 0.2]
#  [5.3 3.7 1.5 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
# ...

# %%
#calculate mean median stddev of first column
print(np.mean(file[:,0]))
# Out:
# 5.843333333333334

# %%
#calculate correlation coefficcient between 1st and 4th colum
#help(corrcoef)
print(np.corrcoef(file[:,0], file[:,3]))
# Out:
# [[1.         0.81795363]
#  [0.81795363 1.        ]]

# %%
#resize add 5 rows
np.resize(file, (155,4)).shape
# Out:
# (155, 4)

# %%
#append add five new rows of random numbers between 30 and 40
rdm = np.random.randint(30, 40, (5, 4))
print(rdm)
